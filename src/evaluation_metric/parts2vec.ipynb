# %%
from glob import glob
import random
import math

import numpy as np
import ipyplot
from PIL import Image
from sklearn.cluster import KMeans
from itertools import compress
import pickle
import pandas as pd
import cv2
import ipyplot
import gensim
from ast import literal_eval

from ShufflePatchModel16 import ShufflePatchFeatureExtractor
from VggFeatureExtractor import VggFeatureExtractor
from MoCoFeatureExtractor import MoCoFeatureExtractor

# %% [markdown]
# ### Parameters and Utility methods for extracting patches

# %%
window_size = 32
stride = 24
kp_margin = 16 # keypoint detector has a margin around image where it can not find keypoints
n_clusters = 100

max_files = 1000

walk_length = 10
walks_per_image = 100
word_format_string = '{:02d}'

image_scales = [1/3]

cnn = MoCoFeatureExtractor()
#cnn = VggFeatureExtractor()
#cnn = ShufflePatchFeatureExtractor("/Users/racoon/Desktop/rotation_jigsaw_migrated_0710_0.0001_1.9522_43.62.pt")

def extract_windows(frame, pos, window_size):
    windows = np.empty((len(pos), window_size, window_size, 3), dtype=np.uint8)

    for i in range(len(pos)):
        windows[i] = extract_window(frame, pos[i], window_size)

    return windows


def extract_window(frame, pos, window_size):
    half_w = window_size/2.0

    top_left = [int(round(pos[0]-half_w)), int(round(pos[1]-half_w))]
    bottom_right = [top_left[0]+window_size, top_left[1]+window_size]

    return frame[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]



def get_rad_grid(grid_pos, rad, grid_shape):

    top_left = (grid_pos[0]-rad, grid_pos[1]-rad)

    res = []

    for i in range(2*rad+1):
        p = (top_left[0]+i, top_left[1])
        if p[0] >= 0 and p[1] >= 0 and p[0] < grid_shape[0] and p[1] < grid_shape[1]:
            res.append(p)
 
    for i in range(2*rad+1):
        p = (top_left[0]+i, top_left[1]+(2*rad))
        if p[0] >= 0 and p[1] >= 0 and p[0] < grid_shape[0] and p[1] < grid_shape[1]:
            res.append(p)

    for i in range(2*rad-1):
        p = (top_left[0], top_left[1]+(i+1))
        if p[0] >= 0 and p[1] >= 0 and p[0] < grid_shape[0] and p[1] < grid_shape[1]:
            res.append(p)

    for i in range(2*rad-1):
        p = (top_left[0]+(2*rad), top_left[1]+(i+1))
        if p[0] >= 0 and p[1] >= 0 and p[0] < grid_shape[0] and p[1] < grid_shape[1]:
            res.append(p)

    return res



def next_pos(salient_grid_positions, grid_shape, current_position):
    
    if current_position is not None:

        rad_grid = get_rad_grid(current_position, 1, grid_shape)

        # print('rad_grid', current_position, rad_grid)
        
        if len(rad_grid) == 0:
            print("frame empty?")
            
        else:
            random.shuffle(rad_grid)
            for loc in rad_grid:
                if loc in salient_grid_positions:
                    return loc
    
    return random.sample(salient_grid_positions,1)[0]

# %% [markdown]
# ### Sample and cluster patches
# This simply uses a fixed grid system. Future patch sampling methods could incorporate an intrest point detector.

# %%
image_files = glob("dataset_100/train/*/*.jpg")[:max_files]

X = []
#P = []

for image_scale in image_scales:
    for idx, image_file in enumerate(image_files):
        print(idx, image_scale, image_file)
        pil_image = Image.open(image_file).convert('RGB')
        pil_image = pil_image.resize((int(round(pil_image.size[0] * image_scale)), int(round(pil_image.size[1] * image_scale))))
        image = np.array(pil_image)

        margin = max(window_size, kp_margin*2)
        grid_shape = (math.floor((image.shape[0] - margin) / stride), math.floor((image.shape[1] - margin) / stride))
        offsets = (round((image.shape[0] - grid_shape[0] * stride)/2), round((image.shape[1] - grid_shape[1] * stride)/2))

        points = [(offsets[0]+y*stride+stride/2,offsets[1]+x*stride+stride/2) for y in range(grid_shape[0]) for x in range(grid_shape[1])]

        patches = extract_windows(image, points, window_size)

        #P.extend(list(patches))

        windows = patches.astype(np.float64)

        feats = cnn.evalRGB(windows)
        print('feats.shape', feats.shape, windows.shape)
        feats = feats.reshape((windows.shape[0], 512))
        X.extend(list(feats))


print("Clustering with KMeans")
clusters = KMeans(n_clusters=n_clusters, verbose=False)
clusters.fit(np.array(X, dtype=np.float32))

cluster_count = len(np.unique(clusters.labels_))
print("done")

pickle.dump(clusters, open("clusters.pkl", "wb"))

# for i in range(cluster_count):
#     print([j for (j, x) in enumerate(clusters.labels_) if x == i])
#     patch_cluster_samples = [P[j] for (j, x) in enumerate(clusters.labels_) if x == i][:10]
#     ipyplot.plot_images(patch_cluster_samples)
# Out:
# 0 0.3333333333333333 dataset_100/train/car/46938b4c628ce00e.jpg
# feats.shape (84, 2048, 1, 1) (84, 32, 32, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-28bd1e44f348> in <module>
#      25         feats = cnn.evalRGB(windows)
#      26         print('feats.shape', feats.shape, windows.shape)
# ---> 27         feats = feats.reshape((windows.shape[0], 512))
#      28         X.extend(list(feats))
#      29
#
# ValueError: cannot reshape array of size 172032 into shape (84,512)

# %% [markdown]
# ### Generate sequence dataset with random walks

# %%
def salient_grid_locations(image, stride, grid_shape, offsets, orb, mask = None):
    
    if mask is not None:
        object_grid_locations = set()

        for y in range(grid_shape[0]):
            for x in range(grid_shape[1]):
                p = (offsets[0] + y * stride + 0.5 * stride, offsets[1] + x * stride + 0.5 * stride)
                w = extract_window(mask, p, stride)

                # print(np.sum(w))
                if np.sum(w) >= stride * stride * 0.3:
                    object_grid_locations.add((y, x))
                
                
    kp = orb.detect(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY), None)

    grid = set()

    for k in kp:
        p = (k.pt[1], k.pt[0]) 
        g = (int(math.floor((p[0]-offsets[0])/stride)), int(math.floor((p[1]-offsets[1])/stride)))
        
        if g[0] < 0 or g[0] >= grid_shape[0] or g[1] < 0 or g[1] >= grid_shape[1]:
            continue
            
        if mask is not None: 
            if g in object_grid_locations:
                grid.add(g)
        else:
             grid.add(g)
            
    
    return grid


def generate_image_sequences(image_file, image_scale, clusters, feature_extractor, orb, mask_file = None, seq_count=walks_per_image):
    # print("generate_image_sequences", image_file)

    pil_image = Image.open(image_file).convert('RGB')
    pil_image = pil_image.resize((int(round(pil_image.size[0] * image_scale)), int(round(pil_image.size[1] * image_scale))))
    image = np.array(pil_image)

    mask = None
    
    if mask_file is not None:
        pil_mask = Image.open(mask_file).convert('1')
        pil_mask = pil_mask.resize((int(round(pil_mask.size[0] * image_scale)), int(round(pil_mask.size[1] * image_scale))))
        mask = np.array(pil_mask)
        
    
    margin = max(window_size, kp_margin*2)
    grid_shape = (math.floor((image.shape[0] - margin) / stride), math.floor((image.shape[1] - margin) / stride))
    offsets = (round((image.shape[0] - grid_shape[0] * stride)/2), round((image.shape[1] - grid_shape[1] * stride)/2))

    grid_locations_set = salient_grid_locations(image, stride, grid_shape, offsets, orb, mask)
    grid_locations_list = list(grid_locations_set)
    
    # print(grid_shape, grid_locations_list)
    points = [(y*stride + stride/2 + offsets[0], x*stride + stride/2 + offsets[1]) for (y,x) in grid_locations_list]
    
    # print('salient grid locations', grid_shape, len(grid_locations_list), 'of', grid_shape[0] * grid_shape[1])
        
    patches = extract_windows(image, points, window_size)
    windows = patches.astype(np.float64)

    feats = cnn.evalRGB(windows)
    feats = feats.reshape((windows.shape[0], 512))

    grid_cluster_ids = clusters.predict(feats)

    grid_location_to_cluster_id = dict([(grid_locations_list[i], grid_cluster_ids[i]) for i in range(len(grid_locations_list))])
    #grid_location_to_patches = dict([(grid_locations_list[i], patches[i]) for i in range(len(grid_locations_list))])
        
    cluster_seqs = []
    point_seqs = []
    
    for i in range(seq_count):
        cluster_seq = []
        point_seq = []
        
        pos = None
        
        for t in range(walk_length):
            pos = next_pos(grid_locations_set, grid_shape, pos)
            cluster_seq.append(grid_location_to_cluster_id[pos])
            point_seq.append((pos[0]*stride + stride/2 + offsets[0], pos[1]*stride + stride/2 + offsets[1]))
            
        cluster_seqs.append([word_format_string.format(w) for w in cluster_seq])
        point_seqs.append(point_seq)
        #print(seqs[-1])
        
        #ipyplot.plot_images(patch_seq, seq)
        
    return cluster_seqs, point_seqs

# %%
image_files = glob("dataset_100/train/*/*.jpg")[:max_files]
image_files.sort()

clusters = pickle.load(open("clusters.pkl", "rb"))
orb = cv2.ORB_create(nfeatures=100000, fastThreshold=7)


cluster_seqs = []
point_seqs = []
image_file_colummn = []
image_scale_colummn = []

for image_scale in image_scales:
    for idx, image_file in enumerate(image_files):
        print(idx, image_file)
        c_seqs, p_seqs = generate_image_sequences(image_file, image_scale, clusters, cnn, orb)
        cluster_seqs.extend(c_seqs)
        point_seqs.extend(p_seqs)
        image_file_colummn.extend([image_file] * walks_per_image)
        image_scale_colummn.extend([image_scale] * walks_per_image)
    
    
data_frame = pd.DataFrame({'words':cluster_seqs, 'file':image_file_colummn, 'points': point_seqs, 'scale': image_scale_colummn})

data_frame.to_csv('sequences.csv')

print("done")
# Out:
# 0 dataset_100/train/airplane/0276aef954d36f18.jpg
# 1 dataset_100/train/airplane/033045b8afa879ec.jpg
# 2 dataset_100/train/airplane/046ba24119dc2170.jpg
# 3 dataset_100/train/airplane/06c3a9a0ebc0af5d.jpg
# 4 dataset_100/train/airplane/07393565a9b3dd6f.jpg
# 5 dataset_100/train/airplane/074e5b1be1e568f6.jpg
# 6 dataset_100/train/airplane/0b9f3a3b87af742f.jpg
# 7 dataset_100/train/airplane/11b50d4333e1e68c.jpg
# 8 dataset_100/train/airplane/13ab2b3daff530fe.jpg
# 9 dataset_100/train/airplane/177a89876068beb6.jpg
# 10 dataset_100/train/airplane/1a2cdeeba6547bab.jpg
# 11 dataset_100/train/airplane/1a8c1a1a20e5a8ef.jpg
# 12 dataset_100/train/airplane/1bbbc7d31d0e1225.jpg
# 13 dataset_100/train/airplane/1bbf78b691f9cdad.jpg
# 14 dataset_100/train/airplane/1f46a9399acfb6f3.jpg
# 15 dataset_100/train/airplane/22cdb9abd3ac400c.jpg
# 16 dataset_100/train/airplane/2f118b9b64e097ab.jpg
# 17 dataset_100/train/airplane/38d146c322d738ff.jpg
# 18 dataset_100/train/airplane/3976b08facf36cc2.jpg
# 19 dataset_100/train/airplane/3aad6b9135fbd4ea.jpg
# 20 dataset_100/train/airplane/3b902f0d20721ca6.jpg
# 21 dataset_100/train/airplane/3eaf3fe21ccbb7ee.jpg
# 22 dataset_100/train/airplane/400857d0f30f9967.jpg
# 23 dataset_100/train/airplane/40abd4f4edaa5d38.jpg
# 24 dataset_100/train/airplane/42e6f267e93c6448.jpg
# 25 dataset_100/train/airplane/45377046affe4fa5.jpg
# 26 dataset_100/train/airplane/533b566abbbf65cd.jpg
# 27 dataset_100/train/airplane/54a7bb6107b66bf2.jpg
# 28 dataset_100/train/airplane/57085c42429e038b.jpg
# 29 dataset_100/train/airplane/58b2ae1a95780854.jpg
# 30 dataset_100/train/airplane/61e236d3add3c2c1.jpg
# 31 dataset_100/train/airplane/653c866161f6562f.jpg
# 32 dataset_100/train/airplane/6659e3db72bce57f.jpg
# 33 dataset_100/train/airplane/66c6086263debade.jpg
# 34 dataset_100/train/airplane/673a4effdd6618b2.jpg
# 35 dataset_100/train/airplane/6aab4765ce2690fd.jpg
# 36 dataset_100/train/airplane/6fa25b1b70c44395.jpg
# 37 dataset_100/train/airplane/708c10773d7e987c.jpg
# 38 dataset_100/train/airplane/7286c5d8fb0317de.jpg
# 39 dataset_100/train/airplane/73f5da147a33433b.jpg
# 40 dataset_100/train/airplane/74243482c2439fa9.jpg
# 41 dataset_100/train/airplane/77868697d138c1af.jpg
# 42 dataset_100/train/airplane/7ee9a8a85995889c.jpg
# 43 dataset_100/train/airplane/7f71ee3311e6c01f.jpg
# 44 dataset_100/train/airplane/80a1afa01277823c.jpg
# 45 dataset_100/train/airplane/820811dca5558091.jpg
# 46 dataset_100/train/airplane/8759ca2e43ec521b.jpg
# 47 dataset_100/train/airplane/875e00e5a095b197.jpg
# 48 dataset_100/train/airplane/877dc9d3de07e4b2.jpg
# 49 dataset_100/train/airplane/8a1ec7f57a8e8336.jpg
# 50 dataset_100/train/airplane/8ecb7a4da5a31e2a.jpg
# 51 dataset_100/train/airplane/8ee89709b8ce650c.jpg
# 52 dataset_100/train/airplane/91156d7c1d317e30.jpg
# 53 dataset_100/train/airplane/95651c92395e30db.jpg
# 54 dataset_100/train/airplane/9a6933798ef5ac2e.jpg
# 55 dataset_100/train/airplane/9b3058396ec0bd41.jpg
# 56 dataset_100/train/airplane/9c33b5dcedfdcbf6.jpg
# 57 dataset_100/train/airplane/9d89fcec8204e1e6.jpg
# 58 dataset_100/train/airplane/a016492571d99687.jpg
# 59 dataset_100/train/airplane/a095ec6f095bf447.jpg
# 60 dataset_100/train/airplane/a46091cf102d43aa.jpg
# 61 dataset_100/train/airplane/a4e58794bf2da12e.jpg
# 62 dataset_100/train/airplane/a5a56ec06900ac93.jpg
# 63 dataset_100/train/airplane/a5e5d7e6e0df70a5.jpg
# 64 dataset_100/train/airplane/a65cde81a26a3774.jpg
# 65 dataset_100/train/airplane/ac5234895757f983.jpg
# 66 dataset_100/train/airplane/ac7668dafcb1ac70.jpg
# 67 dataset_100/train/airplane/ad274dfc79c5a6eb.jpg
# 68 dataset_100/train/airplane/ad63b93fb150e63c.jpg
# 69 dataset_100/train/airplane/aec17dfec045905e.jpg
# 70 dataset_100/train/airplane/b09ccf3628c16545.jpg
# 71 dataset_100/train/airplane/ba3c48dc3aa1c5cb.jpg
# 72 dataset_100/train/airplane/baee1fe0a3a9b5a6.jpg
# 73 dataset_100/train/airplane/bc3aad0e6abaa23f.jpg
# 74 dataset_100/train/airplane/be535a03639b46d3.jpg
# 75 dataset_100/train/airplane/bef50424c62d12c5.jpg
# 76 dataset_100/train/airplane/c12b5ebde7e7494e.jpg
# 77 dataset_100/train/airplane/c5ade8b3c186c52e.jpg
# 78 dataset_100/train/airplane/c71a400f59ba65eb.jpg
# 79 dataset_100/train/airplane/c9553bbcd6a79660.jpg
# 80 dataset_100/train/airplane/caa75844ec6542b5.jpg
# 81 dataset_100/train/airplane/cd8ab636fd09959b.jpg
# 82 dataset_100/train/airplane/ceb2a8c74a7078d8.jpg
# 83 dataset_100/train/airplane/ceb5c04d8be5217b.jpg
# 84 dataset_100/train/airplane/cf4d0c782e7fa7b5.jpg
# 85 dataset_100/train/airplane/d349aafa85911e78.jpg
# 86 dataset_100/train/airplane/d7b7fcb2ba39c31a.jpg
# 87 dataset_100/train/airplane/db0b70644c2bc2a6.jpg
# 88 dataset_100/train/airplane/defea4177e106598.jpg
# 89 dataset_100/train/airplane/e081616be90edbfa.jpg
# 90 dataset_100/train/airplane/e2e6d0cfa89ee9fa.jpg
# 91 dataset_100/train/airplane/e7221f383df3dceb.jpg
# 92 dataset_100/train/airplane/ea1573d80c57c17c.jpg
# 93 dataset_100/train/airplane/ea7907d9f3cea615.jpg
# 94 dataset_100/train/airplane/eda11dda88e91dd3.jpg
# 95 dataset_100/train/airplane/edea9c57f36f03ad.jpg
# 96 dataset_100/train/airplane/ee800d7260b9152d.jpg
# 97 dataset_100/train/airplane/ee839b00acc539e9.jpg
# 98 dataset_100/train/airplane/f8234574d2285fbc.jpg
# 99 dataset_100/train/airplane/ff4aa111145fdec8.jpg
# 100 dataset_100/train/car/0104cba3ff87376c.jpg
# 101 dataset_100/train/car/02c0f07948ac1eb9.jpg
# 102 dataset_100/train/car/068921685a717645.jpg
# 103 dataset_100/train/car/0a41cda5f44baaf6.jpg
# 104 dataset_100/train/car/0a7be0b883a12966.jpg
# 105 dataset_100/train/car/0b1359c23700cb4c.jpg
# 106 dataset_100/train/car/0c9f9b713f229fba.jpg
# 107 dataset_100/train/car/0e28560eebe0f1f4.jpg
# 108 dataset_100/train/car/0f3155c67ef49ad5.jpg
# 109 dataset_100/train/car/10deaafff8740957.jpg
# 110 dataset_100/train/car/126c44183c41ab28.jpg
# 111 dataset_100/train/car/140e8d10ff02e7e7.jpg
# 112 dataset_100/train/car/16808d79a12659c2.jpg
# 113 dataset_100/train/car/18601389796b9296.jpg
# 114 dataset_100/train/car/1bfa911039ff82fb.jpg
# 115 dataset_100/train/car/1ed277062bc9b8b8.jpg
# 116 dataset_100/train/car/1f34454c4c073e1b.jpg
# 117 dataset_100/train/car/20feebf45620cc76.jpg
# 118 dataset_100/train/car/22b47020c3f23138.jpg
# 119 dataset_100/train/car/230960886121a41a.jpg
# 120 dataset_100/train/car/23698d4b7ec48819.jpg
# 121 dataset_100/train/car/240d6d636ae47e4c.jpg
# 122 dataset_100/train/car/2d1397e3f603b83b.jpg
# 123 dataset_100/train/car/33922016c7c98c3b.jpg
# 124 dataset_100/train/car/339b043b9f762f10.jpg
# 125 dataset_100/train/car/3592db0ce6e1ad08.jpg
# 126 dataset_100/train/car/381dbf99a0cc05f8.jpg
# 127 dataset_100/train/car/3925ba5f382af5bd.jpg
# 128 dataset_100/train/car/3c613b1aa9fa1bbf.jpg
# 129 dataset_100/train/car/3fe04f7604431846.jpg
# 130 dataset_100/train/car/40ab29a060cb9eb4.jpg
# 131 dataset_100/train/car/456439ac45f0f784.jpg
# 132 dataset_100/train/car/45c5a5823458b1e0.jpg
# 133 dataset_100/train/car/46938b4c628ce00e.jpg
# 134 dataset_100/train/car/4fc6cb9df6ea675f.jpg
# 135 dataset_100/train/car/500e127b95028a6d.jpg
# 136 dataset_100/train/car/50784a0961216133.jpg
# 137 dataset_100/train/car/50bc64a88e14f9fb.jpg
# 138 dataset_100/train/car/5206ff75a1e480b0.jpg
# 139 dataset_100/train/car/538dcb5018297a56.jpg
# 140 dataset_100/train/car/5e9ef1ccc144e4d5.jpg
# 141 dataset_100/train/car/5ff817e7b606a605.jpg
# 142 dataset_100/train/car/60f2e6435743ea37.jpg
# 143 dataset_100/train/car/66fb599a59a53707.jpg
# 144 dataset_100/train/car/6b27c58d912aef06.jpg
# 145 dataset_100/train/car/6cb37347c1ff659f.jpg
# 146 dataset_100/train/car/6ec05587fb50f81d.jpg
# 147 dataset_100/train/car/72d9aa6212accc52.jpg
# 148 dataset_100/train/car/7306f88e950a43b8.jpg
# 149 dataset_100/train/car/74f69cb250f92326.jpg
# 150 dataset_100/train/car/79d158aa4408e5fe.jpg
# 151 dataset_100/train/car/7e0311e4960a1563.jpg
# 152 dataset_100/train/car/7e1ae78fe2c0882f.jpg
# 153 dataset_100/train/car/836f610f7271d595.jpg
# 154 dataset_100/train/car/87a618d5e8e769f4.jpg
# 155 dataset_100/train/car/88e5a3fe3fb0b71e.jpg
# 156 dataset_100/train/car/8aaa6d4955ffe5b7.jpg
# 157 dataset_100/train/car/8b08690c2f1e57ac.jpg
# 158 dataset_100/train/car/8c4b9d096f6423ed.jpg
# 159 dataset_100/train/car/8e01b9d1471238ff.jpg
# 160 dataset_100/train/car/8ea87a001d8fed5c.jpg
# 161 dataset_100/train/car/930dc3d41c3dd8b0.jpg
# 162 dataset_100/train/car/988abe381c6daf10.jpg
# 163 dataset_100/train/car/9893ae3d876f9c1c.jpg
# 164 dataset_100/train/car/9db4b3227af3862e.jpg
# 165 dataset_100/train/car/9ff761715da8db4a.jpg
# 166 dataset_100/train/car/a37ef652b5a253ba.jpg
# 167 dataset_100/train/car/a87aabe7ced084da.jpg
# 168 dataset_100/train/car/afe1daabdf696287.jpg
# 169 dataset_100/train/car/b7ac79133f230248.jpg
# 170 dataset_100/train/car/be51f7840abc3b89.jpg
# 171 dataset_100/train/car/c1ae01ffc0c505f4.jpg
# 172 dataset_100/train/car/c242644c195aef4b.jpg
# 173 dataset_100/train/car/c4b4aad15b0d20b6.jpg
# 174 dataset_100/train/car/c6f0bd65f2c04cc8.jpg
# 175 dataset_100/train/car/c8698f0073819905.jpg
# 176 dataset_100/train/car/cedf056ecd56e66d.jpg
# 177 dataset_100/train/car/cef82902c2f6cac2.jpg
# 178 dataset_100/train/car/d14658b78cec2cf7.jpg
# 179 dataset_100/train/car/d228e5e664cae432.jpg
# 180 dataset_100/train/car/d29650a6404a2fff.jpg
# 181 dataset_100/train/car/d3729058c6a4186e.jpg
# 182 dataset_100/train/car/d5c700f6f7d5d15f.jpg
# 183 dataset_100/train/car/d69642784c6741ec.jpg
# 184 dataset_100/train/car/d7b71c9fd144d58d.jpg
# 185 dataset_100/train/car/d9693518440b0b06.jpg
# 186 dataset_100/train/car/dafb540b5ee8488a.jpg
# 187 dataset_100/train/car/dcd02dd2a9cdc670.jpg
# 188 dataset_100/train/car/dd372c93febdfb3b.jpg
# 189 dataset_100/train/car/dda6a3de709a89cc.jpg
# 190 dataset_100/train/car/e1b101465df68788.jpg
# 191 dataset_100/train/car/e79c15a7a0768fc7.jpg
# 192 dataset_100/train/car/ea9a6d46a1279f85.jpg
# 193 dataset_100/train/car/eac45380074ba8c8.jpg
# 194 dataset_100/train/car/eecd66089649f982.jpg
# 195 dataset_100/train/car/f24929aff8c7b260.jpg
# 196 dataset_100/train/car/f3c07279aed5f8d9.jpg
# 197 dataset_100/train/car/f6b73bb2536fdcb7.jpg
# 198 dataset_100/train/car/fc418b3caef440aa.jpg
# 199 dataset_100/train/car/fdd963edc28bf163.jpg
# 200 dataset_100/train/horse/010d42acb7498094.jpg
# 201 dataset_100/train/horse/050e8ca25cd35ba5.jpg
# 202 dataset_100/train/horse/0a4052b537cc7e20.jpg
# 203 dataset_100/train/horse/0ee38e79c504fe1c.jpg
# 204 dataset_100/train/horse/110b48869ee8c4a3.jpg
# 205 dataset_100/train/horse/1175875723f994b1.jpg
# 206 dataset_100/train/horse/129d098f401181ed.jpg
# 207 dataset_100/train/horse/1599c65b23b6f4b4.jpg
# 208 dataset_100/train/horse/1771a6a8ebbc01ad.jpg
# 209 dataset_100/train/horse/1b2c1d18a5469167.jpg
# 210 dataset_100/train/horse/1ea80361811c92ec.jpg
# 211 dataset_100/train/horse/250ab8b4f8396f85.jpg
# 212 dataset_100/train/horse/2b7d4c36406a4395.jpg
# 213 dataset_100/train/horse/2c4683b139ff1685.jpg
# 368 dataset_100/train/other/b1400e477c3d6837.jpg
# 369 dataset_100/train/other/b53f511ebf522fe6.jpg
# 370 dataset_100/train/other/b6de7c44449aca43.jpg
# 371 dataset_100/train/other/b8d6dcbc1ee43a28.jpg
# 372 dataset_100/train/other/ba9cb8884bf69279.jpg
# 373 dataset_100/train/other/bc586ab5154d45ca.jpg
# 374 dataset_100/train/other/bce7bd53b65a472b.jpg
# 375 dataset_100/train/other/ccca79f1e7646f88.jpg
# 376 dataset_100/train/other/d07cd96a7823ccc3.jpg
# 377 dataset_100/train/other/d0bddc66d7903f1c.jpg
# 378 dataset_100/train/other/d62112cb08d5cd79.jpg
# 379 dataset_100/train/other/d91c4fec285d5a0e.jpg
# 380 dataset_100/train/other/e0ca63f8b8033786.jpg
# 381 dataset_100/train/other/e2903d7029b5067d.jpg
# 382 dataset_100/train/other/e32ab8519d7f2998.jpg
# 383 dataset_100/train/other/e3d0e1cc6109fa71.jpg
# 384 dataset_100/train/other/eb99cee1f01b08ff.jpg
# 385 dataset_100/train/other/ec94783ea6030d25.jpg
# 386 dataset_100/train/other/ee690d781df875bd.jpg
# 387 dataset_100/train/other/efa00e5caadb1f82.jpg
# 388 dataset_100/train/other/f1643a92664b2a94.jpg
# 389 dataset_100/train/other/f630e37430b6b139.jpg
# 390 dataset_100/train/other/f63cf7e1f7d8271f.jpg
# 391 dataset_100/train/other/f65b5f243f6633a7.jpg
# 392 dataset_100/train/other/fd0420759eab58b2.jpg
# 0 dataset_100/train/airplane/0276aef954d36f18.jpg
# 1 dataset_100/train/airplane/033045b8afa879ec.jpg
# 2 dataset_100/train/airplane/046ba24119dc2170.jpg
# 3 dataset_100/train/airplane/06c3a9a0ebc0af5d.jpg
# 4 dataset_100/train/airplane/07393565a9b3dd6f.jpg
# 5 dataset_100/train/airplane/074e5b1be1e568f6.jpg
# 6 dataset_100/train/airplane/0b9f3a3b87af742f.jpg
# 7 dataset_100/train/airplane/11b50d4333e1e68c.jpg
# 8 dataset_100/train/airplane/13ab2b3daff530fe.jpg
# 9 dataset_100/train/airplane/177a89876068beb6.jpg
# 10 dataset_100/train/airplane/1a2cdeeba6547bab.jpg
# 11 dataset_100/train/airplane/1a8c1a1a20e5a8ef.jpg
# 12 dataset_100/train/airplane/1bbbc7d31d0e1225.jpg
# 13 dataset_100/train/airplane/1bbf78b691f9cdad.jpg
# 14 dataset_100/train/airplane/1f46a9399acfb6f3.jpg
# 15 dataset_100/train/airplane/22cdb9abd3ac400c.jpg
# 16 dataset_100/train/airplane/2f118b9b64e097ab.jpg
# 17 dataset_100/train/airplane/38d146c322d738ff.jpg
# 18 dataset_100/train/airplane/3976b08facf36cc2.jpg
# 19 dataset_100/train/airplane/3aad6b9135fbd4ea.jpg
# 20 dataset_100/train/airplane/3b902f0d20721ca6.jpg
# 21 dataset_100/train/airplane/3eaf3fe21ccbb7ee.jpg
# 22 dataset_100/train/airplane/400857d0f30f9967.jpg
# 23 dataset_100/train/airplane/40abd4f4edaa5d38.jpg
# 24 dataset_100/train/airplane/42e6f267e93c6448.jpg
# 25 dataset_100/train/airplane/45377046affe4fa5.jpg
# 26 dataset_100/train/airplane/533b566abbbf65cd.jpg
# 27 dataset_100/train/airplane/54a7bb6107b66bf2.jpg
# 28 dataset_100/train/airplane/57085c42429e038b.jpg
# 29 dataset_100/train/airplane/58b2ae1a95780854.jpg
# 30 dataset_100/train/airplane/61e236d3add3c2c1.jpg
# 31 dataset_100/train/airplane/653c866161f6562f.jpg
# 32 dataset_100/train/airplane/6659e3db72bce57f.jpg
# 33 dataset_100/train/airplane/66c6086263debade.jpg
# 34 dataset_100/train/airplane/673a4effdd6618b2.jpg
# 35 dataset_100/train/airplane/6aab4765ce2690fd.jpg
# 36 dataset_100/train/airplane/6fa25b1b70c44395.jpg
# 37 dataset_100/train/airplane/708c10773d7e987c.jpg
# 38 dataset_100/train/airplane/7286c5d8fb0317de.jpg
# 39 dataset_100/train/airplane/73f5da147a33433b.jpg
# 40 dataset_100/train/airplane/74243482c2439fa9.jpg
# 41 dataset_100/train/airplane/77868697d138c1af.jpg
# 42 dataset_100/train/airplane/7ee9a8a85995889c.jpg
# 43 dataset_100/train/airplane/7f71ee3311e6c01f.jpg
# 44 dataset_100/train/airplane/80a1afa01277823c.jpg
# 45 dataset_100/train/airplane/820811dca5558091.jpg
# 46 dataset_100/train/airplane/8759ca2e43ec521b.jpg
# 47 dataset_100/train/airplane/875e00e5a095b197.jpg
# 48 dataset_100/train/airplane/877dc9d3de07e4b2.jpg
# 49 dataset_100/train/airplane/8a1ec7f57a8e8336.jpg
# 50 dataset_100/train/airplane/8ecb7a4da5a31e2a.jpg
# 51 dataset_100/train/airplane/8ee89709b8ce650c.jpg
# 52 dataset_100/train/airplane/91156d7c1d317e30.jpg
# 53 dataset_100/train/airplane/95651c92395e30db.jpg
# 54 dataset_100/train/airplane/9a6933798ef5ac2e.jpg
# 55 dataset_100/train/airplane/9b3058396ec0bd41.jpg
# 56 dataset_100/train/airplane/9c33b5dcedfdcbf6.jpg
# 57 dataset_100/train/airplane/9d89fcec8204e1e6.jpg
# 58 dataset_100/train/airplane/a016492571d99687.jpg
# 59 dataset_100/train/airplane/a095ec6f095bf447.jpg
# 60 dataset_100/train/airplane/a46091cf102d43aa.jpg
# 61 dataset_100/train/airplane/a4e58794bf2da12e.jpg
# 62 dataset_100/train/airplane/a5a56ec06900ac93.jpg
# 63 dataset_100/train/airplane/a5e5d7e6e0df70a5.jpg
# 64 dataset_100/train/airplane/a65cde81a26a3774.jpg
# 65 dataset_100/train/airplane/ac5234895757f983.jpg
# 66 dataset_100/train/airplane/ac7668dafcb1ac70.jpg
# 67 dataset_100/train/airplane/ad274dfc79c5a6eb.jpg
# 68 dataset_100/train/airplane/ad63b93fb150e63c.jpg
# 69 dataset_100/train/airplane/aec17dfec045905e.jpg
# 70 dataset_100/train/airplane/b09ccf3628c16545.jpg
# 71 dataset_100/train/airplane/ba3c48dc3aa1c5cb.jpg
# 72 dataset_100/train/airplane/baee1fe0a3a9b5a6.jpg
# 73 dataset_100/train/airplane/bc3aad0e6abaa23f.jpg
# 74 dataset_100/train/airplane/be535a03639b46d3.jpg
# 75 dataset_100/train/airplane/bef50424c62d12c5.jpg
# 76 dataset_100/train/airplane/c12b5ebde7e7494e.jpg
# 77 dataset_100/train/airplane/c5ade8b3c186c52e.jpg
# 78 dataset_100/train/airplane/c71a400f59ba65eb.jpg
# 79 dataset_100/train/airplane/c9553bbcd6a79660.jpg
# 80 dataset_100/train/airplane/caa75844ec6542b5.jpg
# 81 dataset_100/train/airplane/cd8ab636fd09959b.jpg
# 82 dataset_100/train/airplane/ceb2a8c74a7078d8.jpg
# 83 dataset_100/train/airplane/ceb5c04d8be5217b.jpg
# 84 dataset_100/train/airplane/cf4d0c782e7fa7b5.jpg
# 85 dataset_100/train/airplane/d349aafa85911e78.jpg
# 86 dataset_100/train/airplane/d7b7fcb2ba39c31a.jpg
# 87 dataset_100/train/airplane/db0b70644c2bc2a6.jpg
# 88 dataset_100/train/airplane/defea4177e106598.jpg
# 89 dataset_100/train/airplane/e081616be90edbfa.jpg
# 90 dataset_100/train/airplane/e2e6d0cfa89ee9fa.jpg
# 91 dataset_100/train/airplane/e7221f383df3dceb.jpg
# 92 dataset_100/train/airplane/ea1573d80c57c17c.jpg
# 93 dataset_100/train/airplane/ea7907d9f3cea615.jpg
# 94 dataset_100/train/airplane/eda11dda88e91dd3.jpg
# 95 dataset_100/train/airplane/edea9c57f36f03ad.jpg
# 96 dataset_100/train/airplane/ee800d7260b9152d.jpg
# 97 dataset_100/train/airplane/ee839b00acc539e9.jpg
# 98 dataset_100/train/airplane/f8234574d2285fbc.jpg
# 99 dataset_100/train/airplane/ff4aa111145fdec8.jpg
# 100 dataset_100/train/car/0104cba3ff87376c.jpg
# 101 dataset_100/train/car/02c0f07948ac1eb9.jpg
# 102 dataset_100/train/car/068921685a717645.jpg
# 103 dataset_100/train/car/0a41cda5f44baaf6.jpg
# 104 dataset_100/train/car/0a7be0b883a12966.jpg
# 105 dataset_100/train/car/0b1359c23700cb4c.jpg
# 106 dataset_100/train/car/0c9f9b713f229fba.jpg
# 107 dataset_100/train/car/0e28560eebe0f1f4.jpg
# 108 dataset_100/train/car/0f3155c67ef49ad5.jpg
# 109 dataset_100/train/car/10deaafff8740957.jpg
# 110 dataset_100/train/car/126c44183c41ab28.jpg
# 111 dataset_100/train/car/140e8d10ff02e7e7.jpg
# 112 dataset_100/train/car/16808d79a12659c2.jpg
# 113 dataset_100/train/car/18601389796b9296.jpg
# 114 dataset_100/train/car/1bfa911039ff82fb.jpg
# 115 dataset_100/train/car/1ed277062bc9b8b8.jpg
# 116 dataset_100/train/car/1f34454c4c073e1b.jpg
# 117 dataset_100/train/car/20feebf45620cc76.jpg
# 118 dataset_100/train/car/22b47020c3f23138.jpg
# 119 dataset_100/train/car/230960886121a41a.jpg
# 120 dataset_100/train/car/23698d4b7ec48819.jpg
# 121 dataset_100/train/car/240d6d636ae47e4c.jpg
# 122 dataset_100/train/car/2d1397e3f603b83b.jpg
# 123 dataset_100/train/car/33922016c7c98c3b.jpg
# 124 dataset_100/train/car/339b043b9f762f10.jpg
# 125 dataset_100/train/car/3592db0ce6e1ad08.jpg
# 126 dataset_100/train/car/381dbf99a0cc05f8.jpg
# 127 dataset_100/train/car/3925ba5f382af5bd.jpg
# 128 dataset_100/train/car/3c613b1aa9fa1bbf.jpg
# 129 dataset_100/train/car/3fe04f7604431846.jpg
# 130 dataset_100/train/car/40ab29a060cb9eb4.jpg
# 131 dataset_100/train/car/456439ac45f0f784.jpg
# 132 dataset_100/train/car/45c5a5823458b1e0.jpg
# 133 dataset_100/train/car/46938b4c628ce00e.jpg
# 134 dataset_100/train/car/4fc6cb9df6ea675f.jpg
# 135 dataset_100/train/car/500e127b95028a6d.jpg
# 136 dataset_100/train/car/50784a0961216133.jpg
# 137 dataset_100/train/car/50bc64a88e14f9fb.jpg
# 138 dataset_100/train/car/5206ff75a1e480b0.jpg
# 139 dataset_100/train/car/538dcb5018297a56.jpg
# 140 dataset_100/train/car/5e9ef1ccc144e4d5.jpg
# 141 dataset_100/train/car/5ff817e7b606a605.jpg
# 142 dataset_100/train/car/60f2e6435743ea37.jpg
# 143 dataset_100/train/car/66fb599a59a53707.jpg
# 144 dataset_100/train/car/6b27c58d912aef06.jpg
# 145 dataset_100/train/car/6cb37347c1ff659f.jpg
# 146 dataset_100/train/car/6ec05587fb50f81d.jpg
# 147 dataset_100/train/car/72d9aa6212accc52.jpg
# 148 dataset_100/train/car/7306f88e950a43b8.jpg
# 149 dataset_100/train/car/74f69cb250f92326.jpg
# 150 dataset_100/train/car/79d158aa4408e5fe.jpg
# 151 dataset_100/train/car/7e0311e4960a1563.jpg
# 152 dataset_100/train/car/7e1ae78fe2c0882f.jpg
# 153 dataset_100/train/car/836f610f7271d595.jpg
# 154 dataset_100/train/car/87a618d5e8e769f4.jpg
# 155 dataset_100/train/car/88e5a3fe3fb0b71e.jpg
# 156 dataset_100/train/car/8aaa6d4955ffe5b7.jpg
# 157 dataset_100/train/car/8b08690c2f1e57ac.jpg
# 158 dataset_100/train/car/8c4b9d096f6423ed.jpg
# 159 dataset_100/train/car/8e01b9d1471238ff.jpg
# 160 dataset_100/train/car/8ea87a001d8fed5c.jpg
# 161 dataset_100/train/car/930dc3d41c3dd8b0.jpg
# 162 dataset_100/train/car/988abe381c6daf10.jpg
# 163 dataset_100/train/car/9893ae3d876f9c1c.jpg
# 164 dataset_100/train/car/9db4b3227af3862e.jpg
# 165 dataset_100/train/car/9ff761715da8db4a.jpg
# 166 dataset_100/train/car/a37ef652b5a253ba.jpg
# 167 dataset_100/train/car/a87aabe7ced084da.jpg
# 168 dataset_100/train/car/afe1daabdf696287.jpg
# 169 dataset_100/train/car/b7ac79133f230248.jpg
# 170 dataset_100/train/car/be51f7840abc3b89.jpg
# 171 dataset_100/train/car/c1ae01ffc0c505f4.jpg
# 172 dataset_100/train/car/c242644c195aef4b.jpg
# 173 dataset_100/train/car/c4b4aad15b0d20b6.jpg
# 174 dataset_100/train/car/c6f0bd65f2c04cc8.jpg
# 175 dataset_100/train/car/c8698f0073819905.jpg
# 176 dataset_100/train/car/cedf056ecd56e66d.jpg
# 177 dataset_100/train/car/cef82902c2f6cac2.jpg
# 178 dataset_100/train/car/d14658b78cec2cf7.jpg
# 179 dataset_100/train/car/d228e5e664cae432.jpg
# 180 dataset_100/train/car/d29650a6404a2fff.jpg
# 181 dataset_100/train/car/d3729058c6a4186e.jpg
# 182 dataset_100/train/car/d5c700f6f7d5d15f.jpg
# 183 dataset_100/train/car/d69642784c6741ec.jpg
# 184 dataset_100/train/car/d7b71c9fd144d58d.jpg
# 185 dataset_100/train/car/d9693518440b0b06.jpg
# 186 dataset_100/train/car/dafb540b5ee8488a.jpg
# 187 dataset_100/train/car/dcd02dd2a9cdc670.jpg
# 188 dataset_100/train/car/dd372c93febdfb3b.jpg
# 189 dataset_100/train/car/dda6a3de709a89cc.jpg
# 190 dataset_100/train/car/e1b101465df68788.jpg
# 191 dataset_100/train/car/e79c15a7a0768fc7.jpg
# 192 dataset_100/train/car/ea9a6d46a1279f85.jpg
# 193 dataset_100/train/car/eac45380074ba8c8.jpg
# 194 dataset_100/train/car/eecd66089649f982.jpg
# 195 dataset_100/train/car/f24929aff8c7b260.jpg
# 196 dataset_100/train/car/f3c07279aed5f8d9.jpg
# 197 dataset_100/train/car/f6b73bb2536fdcb7.jpg
# 198 dataset_100/train/car/fc418b3caef440aa.jpg
# 199 dataset_100/train/car/fdd963edc28bf163.jpg
# 200 dataset_100/train/horse/010d42acb7498094.jpg
# 201 dataset_100/train/horse/050e8ca25cd35ba5.jpg
# 202 dataset_100/train/horse/0a4052b537cc7e20.jpg
# 203 dataset_100/train/horse/0ee38e79c504fe1c.jpg
# 204 dataset_100/train/horse/110b48869ee8c4a3.jpg
# 205 dataset_100/train/horse/1175875723f994b1.jpg
# 206 dataset_100/train/horse/129d098f401181ed.jpg
# 207 dataset_100/train/horse/1599c65b23b6f4b4.jpg
# 208 dataset_100/train/horse/1771a6a8ebbc01ad.jpg
# 209 dataset_100/train/horse/1b2c1d18a5469167.jpg
# 210 dataset_100/train/horse/1ea80361811c92ec.jpg
# 211 dataset_100/train/horse/250ab8b4f8396f85.jpg
# 212 dataset_100/train/horse/2b7d4c36406a4395.jpg
# 213 dataset_100/train/horse/2c4683b139ff1685.jpg
# 214 dataset_100/train/horse/2f187eb60ee88bdb.jpg
# 215 dataset_100/train/horse/32d8386f0f1d86fc.jpg
# 216 dataset_100/train/horse/344a9140fb86e57d.jpg
# 217 dataset_100/train/horse/35f80ab5f564b6e9.jpg
# 218 dataset_100/train/horse/363120fc9606aa3e.jpg
# 219 dataset_100/train/horse/3634979d35813305.jpg
# 220 dataset_100/train/horse/395939397d472c3b.jpg
# 221 dataset_100/train/horse/3b593df0c7287c7c.jpg
# 222 dataset_100/train/horse/41bdaba2662e929b.jpg
# 223 dataset_100/train/horse/421a93da4e4152f3.jpg
# 224 dataset_100/train/horse/43b63b93b08622f8.jpg
# 225 dataset_100/train/horse/4468a07bd913bf07.jpg
# 226 dataset_100/train/horse/465cc20ecb9331de.jpg
# 227 dataset_100/train/horse/49e54efc9f23e28b.jpg
# 228 dataset_100/train/horse/4a135939062bd5ab.jpg
# 229 dataset_100/train/horse/4abd3aedae89a2f6.jpg
# 230 dataset_100/train/horse/4c11224ef1f9edde.jpg
# 231 dataset_100/train/horse/519e416a87403ee4.jpg
# 232 dataset_100/train/horse/53226f049404e36f.jpg
# 233 dataset_100/train/horse/5498ead4b3d9952b.jpg
# 234 dataset_100/train/horse/5ee307b41af3b342.jpg
# 235 dataset_100/train/horse/5fa0491945756036.jpg
# 236 dataset_100/train/horse/6270e63bf8e7714f.jpg
# 237 dataset_100/train/horse/63094843f786d6fc.jpg
# 238 dataset_100/train/horse/64b9dbca8f5c9269.jpg
# 239 dataset_100/train/horse/68fadfcaa8da8ee6.jpg
# 240 dataset_100/train/horse/69476f44199f3851.jpg
# 241 dataset_100/train/horse/6988acce13e325c2.jpg
# 242 dataset_100/train/horse/6bab709b1b7b49ff.jpg
# 243 dataset_100/train/horse/6cd42c16edae66ba.jpg
# 244 dataset_100/train/horse/6eb53f2b93013759.jpg
# 245 dataset_100/train/horse/7063a68ede6decf6.jpg
# 246 dataset_100/train/horse/71d4905fad74916e.jpg
# 247 dataset_100/train/horse/75489b3b21039330.jpg
# 248 dataset_100/train/horse/79f05a7244ccfcf7.jpg
# 249 dataset_100/train/horse/7f2a4ec24014c5bd.jpg
# 250 dataset_100/train/horse/8236fa11d57936cd.jpg
# 251 dataset_100/train/horse/833212810ef0c76b.jpg
# 252 dataset_100/train/horse/84d5be401d72ef8e.jpg
# 253 dataset_100/train/horse/84f6c0509ebc5173.jpg
# 254 dataset_100/train/horse/8617694c95033edf.jpg
# 255 dataset_100/train/horse/86362f15c5354ebc.jpg
# 256 dataset_100/train/horse/877aa35f42d9804b.jpg
# 257 dataset_100/train/horse/87ea34b7a6c3838c.jpg
# 258 dataset_100/train/horse/8f4e64879f17fb36.jpg
# 259 dataset_100/train/horse/933db5e8ec6ba110.jpg
# 260 dataset_100/train/horse/956c152898884f89.jpg
# 261 dataset_100/train/horse/9a4ba3defe7af18b.jpg
# 262 dataset_100/train/horse/9e9042fbbdc7b831.jpg
# 263 dataset_100/train/horse/a1460a2a0400f681.jpg
# 264 dataset_100/train/horse/a2e84350712351b7.jpg
# 265 dataset_100/train/horse/a4c5d7b12990555c.jpg
# 266 dataset_100/train/horse/a6d53cc2cfa9b2d2.jpg
# 267 dataset_100/train/horse/a7f4ab4e7b501e74.jpg
# 268 dataset_100/train/horse/a9e4e1c802bcaee5.jpg
# 269 dataset_100/train/horse/aca1f97a74701d64.jpg
# 270 dataset_100/train/horse/b19a6d83e91913a8.jpg
# 271 dataset_100/train/horse/b3eb52ee7829ed01.jpg
# 272 dataset_100/train/horse/b793c3cd82e1b00e.jpg
# 273 dataset_100/train/horse/c0762f4b3f97eaca.jpg
# 274 dataset_100/train/horse/c38c1eaa1ac511d5.jpg
# 275 dataset_100/train/horse/cc143092810f871b.jpg
# 276 dataset_100/train/horse/ce5a943d666eaa7d.jpg
# 277 dataset_100/train/horse/d1a9733014ce4e89.jpg
# 278 dataset_100/train/horse/d475802825b0fd44.jpg
# 279 dataset_100/train/horse/d7173d381b09ac66.jpg
# 280 dataset_100/train/horse/d7e0a40ffb2d0cbe.jpg
# 281 dataset_100/train/horse/d7f48eef89b429ff.jpg
# 282 dataset_100/train/horse/d8f58bbbab7f803f.jpg
# 283 dataset_100/train/horse/d9cc58f72a51e6f1.jpg
# 284 dataset_100/train/horse/dd393b8fcb4e88a3.jpg
# 285 dataset_100/train/horse/de5f41e9f8b2512a.jpg
# 286 dataset_100/train/horse/e220e4b6cad10f5c.jpg
# 287 dataset_100/train/horse/e96e29141cab0bc6.jpg
# 288 dataset_100/train/horse/ef16811282f0f570.jpg
# 289 dataset_100/train/horse/f18b25be96809c40.jpg
# 290 dataset_100/train/horse/f88b1b035c47011b.jpg
# 291 dataset_100/train/horse/fe84e4aaedc15ca5.jpg
# 292 dataset_100/train/horse/ffeac105c9e17568.jpg
# 293 dataset_100/train/other/063b11e981ae1db4.jpg
# 294 dataset_100/train/other/08d5936efaa457f9.jpg
# 295 dataset_100/train/other/1268ab795838b2dc.jpg
# 296 dataset_100/train/other/138e90a98e1fda99.jpg
# 297 dataset_100/train/other/148aa1f69209814f.jpg
# 298 dataset_100/train/other/160d56162dc85876.jpg
# 299 dataset_100/train/other/169d1dc07bda560a.jpg
# 300 dataset_100/train/other/19be5e3b0cba73bb.jpg
# 301 dataset_100/train/other/1b284cf16c8fd8d3.jpg
# 302 dataset_100/train/other/1cd8845d9ae7fe1d.jpg
# 303 dataset_100/train/other/1d88df5d7e3920c8.jpg
# 304 dataset_100/train/other/1e3791a88b656c6a.jpg
# 305 dataset_100/train/other/208da41aaf6b4725.jpg
# 306 dataset_100/train/other/2310a9d90806ca38.jpg
# 307 dataset_100/train/other/2912d9097d7d6107.jpg
# 308 dataset_100/train/other/29666ecb749713d0.jpg
# 309 dataset_100/train/other/2b44d736b72d8cdd.jpg
# 310 dataset_100/train/other/2ce26cb5ae029ca9.jpg
# 311 dataset_100/train/other/2d22708883788e8b.jpg
# 312 dataset_100/train/other/3303385509bfb011.jpg
# 313 dataset_100/train/other/3e6fafdae70e47c8.jpg
# 314 dataset_100/train/other/3e7203df7270b059.jpg
# 315 dataset_100/train/other/3e736e4318fd0f1a.jpg
# 316 dataset_100/train/other/3f802dc654eea602.jpg
# 317 dataset_100/train/other/4354af969d59835e.jpg
# 318 dataset_100/train/other/4a8a66861e06950b.jpg
# 319 dataset_100/train/other/4ec4c93c3e6cbc2a.jpg
# 320 dataset_100/train/other/5105e40ffa169f06.jpg
# 321 dataset_100/train/other/515486af5c27a2f0.jpg
# 322 dataset_100/train/other/52c5fab85897c7b3.jpg
# 323 dataset_100/train/other/535c2a3ed09247c8.jpg
# 324 dataset_100/train/other/537fcd028b47bc5f.jpg
# 325 dataset_100/train/other/5c4d55f49dedd79f.jpg
# 326 dataset_100/train/other/5d4327db61b2216f.jpg
# 327 dataset_100/train/other/6106517c7d5cd2d1.jpg
# 328 dataset_100/train/other/633e764a10fc5951.jpg
# 329 dataset_100/train/other/648f3f07d1087191.jpg
# 330 dataset_100/train/other/69afae00d78ac1ef.jpg
# 382 dataset_100/train/other/e32ab8519d7f2998.jpg
# 383 dataset_100/train/other/e3d0e1cc6109fa71.jpg
# 384 dataset_100/train/other/eb99cee1f01b08ff.jpg
# 385 dataset_100/train/other/ec94783ea6030d25.jpg
# 386 dataset_100/train/other/ee690d781df875bd.jpg
# 387 dataset_100/train/other/efa00e5caadb1f82.jpg
# 388 dataset_100/train/other/f1643a92664b2a94.jpg
# 389 dataset_100/train/other/f630e37430b6b139.jpg
# 390 dataset_100/train/other/f63cf7e1f7d8271f.jpg
# 391 dataset_100/train/other/f65b5f243f6633a7.jpg
# 392 dataset_100/train/other/fd0420759eab58b2.jpg
# done

# %%
class callback(gensim.models.callbacks.CallbackAny2Vec):
    '''Callback to print loss after each epoch.'''

    def __init__(self):
        self.epoch = 0

    def on_epoch_end(self, model):
        print('epoch {}'.format(self.epoch))
        self.epoch += 1
              
def read_corpus(fname, tokens_only=False):
    data_frame = pd.read_csv('sequences.csv',converters={"words": literal_eval, "points": literal_eval})
    
    for index, row in data_frame.iterrows():
        if tokens_only:
            yield row['words']
        else:
            yield gensim.models.doc2vec.TaggedDocument(row['words'], [index])

train_corpus = list(read_corpus('sequences.csv'))
print(train_corpus[:2])

model = gensim.models.doc2vec.Doc2Vec(vector_size=50, epochs=40)
model.build_vocab(train_corpus)
model.train(train_corpus, total_examples=model.corpus_count, epochs=model.epochs, callbacks=[callback()])

model.save('doc2vec.model')

print("done")
# Out:
# [TaggedDocument(words=['045', '045', '045', '047', '047', '047', '045', '064', '037', '036'], tags=[0]), TaggedDocument(words=['083', '064', '083', '074', '083', '045', '083', '005', '036', '005'], tags=[1])]
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# epoch 21
# epoch 22
# epoch 23
# epoch 24
# epoch 25
# epoch 26
# epoch 27
# epoch 28
# epoch 29
# epoch 30
# epoch 31
# epoch 32
# epoch 33
# epoch 34
# epoch 35
# epoch 36
# epoch 37
# epoch 38
# epoch 39
# done

# %%
clusters = pickle.load(open("clusters.pkl", "rb"))
orb = cv2.ORB_create(nfeatures=100000, fastThreshold=7)
model = gensim.models.doc2vec.Doc2Vec.load('doc2vec.model')

data_frame = pd.read_csv('sequences.csv',converters={"words": literal_eval, "points": literal_eval})

test_image_files = glob("dataset_100/test/*/*.jpg")
test_mask_files = glob("dataset_100/test/*/*.mask.png")

test_image_files.sort()
test_mask_files.sort()


for image_scale in image_scales:
    
    correct = 0
    total = 0

    for i in range(len(test_image_files)):

        image_file = test_image_files[i]
        mask_file = test_mask_files[i]

        print("test", image_file)

        c_seqs, p_seqs = generate_image_sequences(image_file, image_scale, clusters, cnn, orb, mask_file = mask_file, seq_count=100)
        #print('seqs', seqs)

        vectors = [[model.infer_vector(s)] for s in c_seqs]
        #print('vectors', vectors)

        for v in vectors:
            similar = model.docvecs.most_similar(v, topn=10)
            #print('similar', similar)

            for s in similar:
                f = data_frame.loc[s[0],'file']
                if '/airplane/' in image_file and '/airplane/' in f:
                    correct += 1
                elif '/car/' in image_file and '/car/' in f:
                    correct += 1
                elif '/horse/' in image_file and '/horse/' in f:
                    correct += 1

                #print("similar to", f)

                total += 1
    
    print("score", correct/total)
# Out:
# test dataset_100/test/airplane/35b11a04c24db20c.jpg
# test dataset_100/test/airplane/4ad0f079b979be5d.jpg
# test dataset_100/test/airplane/839ce813ca97084c.jpg
# test dataset_100/test/airplane/93b5bf58149adefd.jpg
# test dataset_100/test/airplane/9dc879c35a26d2d3.jpg
# test dataset_100/test/airplane/a48f1d15812036fa.jpg
