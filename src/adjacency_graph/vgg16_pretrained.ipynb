# %%
import torch
import torchvision.models.vgg as models

input = torch.rand(1, 3, 32, 32)
vgg16 = models.vgg16(pretrained=True)
# vgg16.eval()
output = vgg16.features(input)
print(output)
# Out:
# tensor([[[[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[1.4394]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[0.0000]],
#
#          [[8.6735]],
#
#          [[0.0000]],
#
# ...

# %%
print(output.size())
# Out:
# torch.Size([1, 512, 1, 1])
